# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Data preprocessing

# %%
movies1 = pd.read_csv("Movies.csv")
credits = pd.read_csv("credits.csv")

movies1.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count
# 0  Enter the World of Pandora.  Avatar           7.2       11800

# %% [markdown]
# ## Merge Dataframe

# %%
movies = movies1.merge(credits,on="title")
pd.set_option("display.max_columns", None)
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title  vote_average  vote_count  movie_id  \
# 0  Enter the World of Pandora.  Avatar           7.2       11800     19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# ## Create a new dataframe including only useful column

# %%
Movies = movies[['movie_id','title','overview','genres','keywords','cast',"crew"]]

# %%
Movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %% [markdown]
# ## Remove Null Value

# %%
Movies.isnull().sum()
Movies.dropna(inplace=True)

# %%
Movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %% [markdown]
# ## Create a help function for conver weird form of keyword, tagline and other to normal string

# %%
import ast 

def convert (text):
    l = []
    for i in ast.literal_eval(text):
        l.append(i['name'])

    return l

# %%
Movies["keywords"] = Movies["keywords"].apply(convert)
Movies["genres"] = Movies["genres"].apply(convert)

# %%
def for_cast(text):
    l = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 7:
            l.append(i["name"])
            counter +=1

    return l

# %%
Movies["cast"] = Movies["cast"].apply(for_cast)

# %%
def for_crew(text):
    l = []
    for i in ast.literal_eval(text):
        if i["job"] == "Director" or i["job"] == "Writer":
            l.append(i["name"])

    return l

# %%
Movies["crew"] = Movies["crew"].apply(for_crew)

# %%
Movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                              crew
# 0  [James Cameron, James Cameron]

# %% [markdown]
# ## Remove Space from [genres,keywords,cast,crew]

# %%
def space(text):
    list = []
    for i in text:
        list.append(i.replace(" ",""))
    
    return list

# %%
colm = ['genres','keywords','cast','crew']

for col in colm:
    Movies[col] = Movies[col].apply(space)

# %%
Movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
#
#                                                 cast  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
#
#                            crew
# 0  [JamesCameron, JamesCameron]

# %% [markdown]
# ## Convert List to string

# %%
for col in ['genres','keywords','cast','crew']:
    Movies[col] = Movies[col].apply(lambda x: " ".join(x))

# %% [markdown]
# ## Merge all column and create one Tag

# %%
Movies["tags"] = Movies["overview"]+Movies["genres"]+Movies["keywords"]+Movies["cast"]+Movies["crew"]

# %%
Movies.head(1)
# Out:
#    movie_id   title                                           overview  \
# 0     19995  Avatar  In the 22nd century, a paraplegic Marine is di...
#
#                                     genres  \
# 0  Action Adventure Fantasy ScienceFiction
#
#                                             keywords  \
# 0  cultureclash future spacewar spacecolony socie...
#
#                                                 cast  \
# 0  SamWorthington ZoeSaldana SigourneyWeaver Step...
#
#                         crew  \
# 0  JamesCameron JamesCameron
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...

# %% [markdown]
# ## Final Ready Dataset

# %%
df = Movies[['movie_id','title','tags']]

# %%
df.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...

# %% [markdown]
# # Vectorized

# %% [markdown]
# ## import

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %% [markdown]
# ## Apply stemmer

# %%
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))

    return " ".join(y)

# %%
df["tags"] = df["tags"].apply(stem)

# %% [markdown]
# ## Create vector object

# %%
vector = cv.fit_transform(df["tags"]).toarray()

# %%
np.set_printoptions(threshold=np.inf)
cv.get_feature_names_out()
# Out:
# array(['000', '007', '10', '100', '11', '12', '13', '14', '15', '16',
#        '17', '17th', '18', '18th', '19', '1920', '1930', '1940', '1944',
#        '1950', '1950s', '1960', '1960s', '1970', '1970s', '1971', '1974',
#        '1976', '1980', '1985', '1990', '1999', '19th', '19thcenturi',
#        '20', '200', '2003', '2009', '20th', '21st', '23', '24', '25',
#        '30', '300', '3d', '40', '50', '500', '60', '70', '80', 'aaron',
#        'aaroneckhart', 'aaronseltz', 'abandon', 'abbiecornish', 'abduct',
#        'abigailbreslin', 'abil', 'abl', 'aboard', 'abov', 'abram', 'abus',
#        'academ', 'academi', 'accept', 'access', 'accid', 'accident',
#        'acclaim', 'accompani', 'accomplish', 'account', 'accus', 'ace',
#        'achiev', 'acquaint', 'act', 'action', 'activ', 'activist',
#        'activities', 'actor', 'actress', 'actual', 'adam', 'adambrodi',
#        'adamscott', 'adapt', 'add', 'addict', 'adjust', 'admir', 'admit',
#        'adolesc', 'adopt', 'ador', 'adrienbrodi', 'adult', 'adulteri',
#        'adulthood', 'advanc', 'adventur', 'adventure', 'adventures',
#        'advertis', 'advic', 'advis', 'affair', 'affect', 'afghanistan',
#        'africa', 'african', 'aftercreditssting', 'afterlif', 'aftermath',
#        'ag', 'age', 'agediffer', 'agenc', 'agency', 'agenda', 'agent',
#        'agents', 'aggress', 'ago', 'agre', 'ahead', 'aid', 'aidanquinn',
#        'ail', 'aim', 'air', 'airplan', 'airplanecrash', 'airport', 'aka',
#        'al', 'alabama', 'alan', 'alanalda', 'alanarkin', 'alanrickman',
#        'alantudyk', 'alaska', 'albert', 'alcohol', 'alecbaldwin',
#        'alecguin', 'alessandronivola', 'alex', 'alfredmolina',
#        'alfrewoodard', 'ali', 'alic', 'alice', 'alicebraga', 'aliciawitt',
#        'alien', 'alieninvas', 'alienlife', 'alienplanet', 'aliens',
#        'alik', 'alilart', 'aliv', 'alive', 'allen', 'alli', 'allianc',
#        'allisonjanney', 'allow', 'alon', 'alongsid', 'alpacino', 'alpha',
#        'alreadi', 'alter', 'altern', 'alway', 'alyssa', 'alzheimer',
#        'amanda', 'amandapeet', 'amandaseyfri', 'amateur', 'amaz',
#        'ambassador', 'amberheard', 'ambit', 'ambiti', 'ambul', 'ambush',
#        'america', 'american', 'amid', 'amidst', 'amnesia', 'amp',
#        'amsterdam', 'amus', 'amusementpark', 'amy', 'amyadam', 'amysmart',
#        'analyst', 'ancient', 'ancientworld', 'anderson', 'andi',
#        'andiemacdowel', 'andrew', 'android', 'andy', 'andygarcía',
#        'andysamberg', 'andyserki', 'angel', 'angela', 'angelabassett',
#        'angeles', 'angelinajoli', 'angelo', 'anger', 'angri', 'ani',
#        'anim', 'animalattack', 'animals', 'anjelicahuston', 'ann', 'anna',
#        'annafari', 'annakendrick', 'annapaquin', 'annasophiarobb', 'anne',
#        'annebancroft', 'annehathaway', 'annehech', 'annemoss',
#        'annetteben', 'anni', 'annie', 'announc', 'annual', 'anonym',
#        'anoth', 'answer', 'ant', 'antholog', 'anthoni', 'anthonyanderson',
#        'anthonyhopkin', 'anthonymacki', 'anthropomorph', 'anti', 'antic',
#        'antihero', 'antiqu', 'antoniobandera', 'antonyelchin', 'anyon',
#        'anyth', 'apart', 'apartheid', 'apartment', 'ape', 'apocalyps',
#        'apocalypse', 'apocalypt', 'appar', 'appear', 'appl', 'appoint',
#        'appreci', 'apprentic', 'approach', 'april', 'aquarium', 'arab',
#        'arch', 'archaeologist', 'archeolog', 'archer', 'architect',
#        'arctic', 'area', 'aren', 'arena', 'argument', 'aris',
#        'aristocrat', 'arm', 'armi', 'armiehamm', 'arminmueller', 'armor',
#        'armsdeal', 'army', 'arnold', 'arrang', 'arrest', 'arriv', 'arrog',
#        'art', 'arthur', 'artifact', 'artifici', 'artificialintellig',
#        'artist', 'ash', 'ashley', 'ashleyjudd', 'ashtonkutch', 'asia',
#        'asian', 'asid', 'ask', 'aspect', 'aspir', 'assassin', 'assault',
#        'assembl', 'assign', 'assist', 'assistant', 'associ', 'assum',
#        'asteroid', 'astronaut', 'asylum', 'athlet', 'atom', 'atomicbomb',
#        'attack', 'attacks', 'attempt', 'attempttoescap', 'attend',
#        'attent', 'attic', 'attitud', 'attorney', 'attract', 'audienc',
#        'audit', 'august', 'aunt', 'austin', 'australia', 'australian',
#        'author', 'autism', 'auto', 'aveng', 'averag', 'avoid', 'await',
#        'awak', 'awaken', 'awar', 'award', 'away', 'awkward', 'awri',
#        'awry', 'babe', 'babi', 'baby', 'bachelor', 'backdrop',
#        'background', 'backpack', 'bad', 'bag', 'bahama', 'bail', 'balanc',
#        'ball', 'ballet', 'balloon', 'ban', 'band', 'bandit', 'bangkok',
#        'banish', 'bank', 'banker', 'bankrobb', 'bankrobberi', 'bar',
#        'barbarahershey', 'bare', 'bargain', 'barn', 'barney', 'baron',
#        'barri', 'barrypepp', 'bas', 'base', 'basebal', 'basedoncomicbook',
#        'basedongraphicnovel', 'basedonnovel', 'basedonplay',
#        'basedonstagemus', 'basedontrueev', 'basedontruestori',
#        'basedontvseri', 'basedonvideogam', 'basement', 'basketbal',
#        'basketball', 'batman', 'battl', 'battle', 'battlefield', 'bay',
#        'beach', 'beam', 'bear', 'beard', 'beast', 'beat', 'beauti',
#        'beautiful', 'beautifulwoman', 'beauty', 'becam', 'becaus',
#        'becki', 'becom', 'becominganadult', 'bed', 'bedroom', 'bee',
#        'beer', 'befor', 'befriend', 'began', 'begin', 'begins',
#        'behavior', 'belief', 'believ', 'bell', 'bella', 'belong', 'belov',
#        'ben', 'benaffleck', 'bend', 'beneath', 'benefit', 'benfost',
#        'beniciodeltoro', 'benjamin', 'benjaminbratt', 'benkingsley',
#        'bennett', 'benstil', 'bent', 'berlin', 'berniemac', 'best',
#        'bestfriend', 'bet', 'beth', 'betray', 'better', 'betti',
#        'beverli', 'bibl', 'bid', 'big', 'bigger', 'biggest', 'bike',
#        'biker', 'bikini', 'billcobb', 'billhad', 'billi', 'billionair',
#        'billmoseley', 'billmurray', 'billnighi', 'billpaxton',
#        'billpullman', 'billybobthornton', 'billyburk', 'billyconnolli',
#        'billycrudup', 'billycryst', 'biographi', 'biolog', 'bird',
#        'birth', 'birthday', 'bisexu', 'bishop', 'bit', 'bite', 'bitter',
#        'bizarr', 'black', 'blackmag', 'blackmail', 'blackpeopl', 'blade',
#        'blame', 'blend', 'blind', 'bliss', 'block', 'blond', 'blood',
#        'bloodi', 'bloodsplatt', 'bloodthirsti', 'blow', 'blue',
#        'blythedann', 'board', 'boardingschool', 'boat', 'bob',
#        'bobbalaban', 'bobbi', 'bobgunton', 'bobhoskin', 'bodi', 'body',
#        'bodyguard', 'bold', 'bollywood', 'bomb', 'bond', 'bone',
#        'bonniehunt', 'book', 'border', 'bore', 'boredom', 'born', 'boss',
#        'boston', 'botch', 'bound', 'boundari', 'bounti', 'bountyhunt',
#        'bout', 'box', 'boxer', 'boy', 'boyfriend', 'boys', 'braddourif',
#        'bradleycoop', 'bradpitt', 'brain', 'brainwash', 'brand',
#        'brandon', 'brave', 'braveri', 'brazil', 'brazilian', 'break',
#        'breakdown', 'breakup', 'breast', 'breath', 'breckinmey', 'breed',
#        'brendanfras', 'brendangleeson', 'brent', 'brian', 'briancox',
#        'briandennehi', 'bride', 'bridesmaid', 'bridg', 'brief',
#        'brielarson', 'brien', 'bright', 'brilliant', 'bring', 'brink',
#        'britain', 'british', 'britishsecretservic', 'brittanymurphi',
#        'broadcast', 'broadway', 'broke', 'broken', 'broker', 'brook',
#        'brooklyn', 'broom', 'brothel', 'brother',
#        'brotherbrotherrelationship', 'brothers',
#        'brothersisterrelationship', 'brought', 'brown', 'bruce',
#        'brucedern', 'brucegreenwood', 'brucemcgil', 'brucewilli',
#        'brutal', 'bu', 'buck', 'bud', 'buddi', 'buddy', 'buddycomedi',
#        'budget', 'build', 'building', 'built', 'bullet', 'bulli', 'bumbl',
#        'bunch', 'bunker', 'bunni', 'burglar', 'buri', 'burn',
#        'burtreynold', 'bush', 'busi', 'business', 'businessman', 'bust',
#        'butcher', 'butler', 'butt', 'button', 'buy', 'buzz', 'byrn',
#        'cabin', 'caesar', 'cage', 'cal', 'california', 'calvin',
#        'camcord', 'came', 'camera', 'cameraman', 'cameron', 'camerondiaz',
#        'camgigandet', 'camp', 'campaign', 'campbel', 'campbell', 'campu',
#        'canada', 'canadian', 'cancer', 'candid', 'canin', 'cannib',
#        'capabl', 'capit', 'capt', 'captain', 'captiv', 'captur', 'car',
#        'caraccid', 'carchas', 'carcrash', 'card', 'care', 'career',
#        'carefre', 'caretak', 'caribbean', 'carjourney', 'carl',
#        'carlagugino', 'carmen', 'carol', 'carolina', 'carrac', 'carri',
#        'carrie', 'carriefish', 'cartel', 'carter', 'cartoon', 'cary',
#        'caryelw', 'case', 'caseyaffleck', 'cash', 'casino', 'cast',
#        'castl', 'cat', 'cataclysm', 'catastroph', 'catch',
#        'cateblanchett', 'catherinekeen', 'catherineo', 'catherinezeta',
#        'cathol', 'catholic', 'cattl', 'caught', 'caus', 'cave',
#        'cedrictheentertain', 'celebr', 'celebration', 'cell', 'cellphon',
#        'cemeteri', 'center', 'centr', 'central', 'centuri', 'centuries',
#        'century', 'ceo', 'certain', 'chad', 'chadmichaelmurray', 'chain',
#        'chainsaw', 'challeng', 'champion', 'championship', 'chanc',
#        'chance', 'chang', 'change', 'changed', 'changes', 'channingtatum',
#        'chao', 'chaos', 'chaotic', 'chapter', 'charact', 'character',
#        'characters', 'charg', 'charismat', 'charl', 'charlesd',
#        'charlesdurn', 'charless', 'charli', 'charlie', 'charliesheen',
#        'charlizetheron', 'charlotterampl', 'charm', 'chart', 'chase',
#        'chauffeur', 'chazzpalminteri', 'cheat', 'check', 'cheechmarin',
#        'cheerlead', 'chef', 'chemic', 'chicago', 'chicken', 'chief',
#        'child', 'childhero', 'childhood', 'children', 'chill',
#        'chimcbrid', 'chimp', 'china', 'chines', 'chip', 'chloe',
#        'chloëgracemoretz', 'chloësevigni', 'choic', 'choice', 'choos',
#        'chosen', 'chri', 'chriscoop', 'chrisevan', 'chrishemsworth',
#        'chrisklein', 'chriso', 'chrispin', 'chrispratt', 'chrisrock',
#        'christ', 'christian', 'christianbal', 'christianslat', 'christin',
#        'christinaappleg', 'christinaricci', 'christma', 'christmas',
#        'christmasparti', 'christoph', 'christopherguest', 'christopherle',
#        'christopherlloyd', 'christophermcdonald', 'christophermintz',
#        'christopherplumm', 'christopherwalken', 'christophwaltz',
#        'chronicl', 'chuck', 'church', 'cia', 'ciaránhind',
#        'cigarettesmok', 'cillianmurphi', 'cinema', 'circl', 'circu',
#        'circuit', 'circumst', 'citi', 'citizen', 'city', 'civil',
#        'civilian', 'claim', 'clair', 'clairedan', 'claireforlani', 'clan',
#        'clancybrown', 'clark', 'clarkgregg', 'clash', 'class',
#        'classdiffer', 'classic', 'classmat', 'classroom', 'claudevandamm',
#        'clay', 'cleaduval', 'clean', 'clear', 'clerk', 'clever', 'client',
#        'clients', 'cliffcurti', 'climat', 'climb', 'cliveowen', 'clock',
#        'clone', 'clorisleachman', 'close', 'closer', 'clown', 'club',
#        'clue', 'clutch', 'coach', 'coast', 'cocain', 'code', 'coffin',
#        'cohen', 'col', 'cold', 'coldwar', 'cole', 'colehaus', 'colin',
#        'colinfarrel', 'colinfirth', 'collaps', 'colleagu', 'collect',
#        'collector', 'colleg', 'college', 'collid', 'collin', 'collis',
#        'colombia', 'colonel', 'coloni', 'color', 'colorado', 'coma',
#        'combat', 'combin', 'come', 'comeback', 'comed', 'comedi',
#        'comedian', 'comedy', 'comedygay', 'comedyholiday',
#        'comedynewyork', 'comedyprison', 'comedysex', 'comet', 'comfort',
#        'comic', 'coming', 'comingofag', 'comingout', 'command',
#        'commando', 'commerci', 'commiss', 'commit', 'common', 'commun',
#        'communist', 'community', 'compani', 'companion', 'company',
#        'compet', 'competit', 'competition', 'complet', 'complex',
#        'complic', 'compos', 'compton', 'compuls', 'comput',
#        'computerviru', 'conan', 'concern', 'concert', 'condit', 'confess',
#        'confid', 'conflict', 'confront', 'confus', 'congress', 'conman',
#        'connect', 'connel', 'connienielsen', 'connor', 'conquer',
#        'consequ', 'consequences', 'conserv', 'consid', 'conspir',
#        'conspiraci', 'conspiracy', 'constant', 'constantli', 'construct',
#        'consum', 'contact', 'contain', 'contemporari', 'contend',
#        'content', 'contest', 'continu', 'contract', 'contractor',
#        'control', 'controversi', 'convent', 'converg', 'convers',
#        'convict', 'convinc', 'cook', 'cool', 'cooper', 'cop', 'cope',
#        'cops', 'core', 'corner', 'corp', 'corpor', 'corporation', 'corps',
#        'corrupt', 'cost', 'costum', 'couldn', 'counselor', 'count',
#        'countless', 'countri', 'country', 'countryhous', 'countrymus',
#        'countrysid', 'coup', 'coupl', 'couple', 'courag', 'cours',
#        'court', 'courtcas', 'courteneycox', 'cousin', 'cover', 'covert',
#        'covet', 'cow', 'cowardli', 'cowboy', 'crab', 'crack', 'craft',
#        'craig', 'craigt', 'crane', 'crash', 'crave', 'crazi', 'creat',
#        'creation', 'creativ', 'creator', 'creatur', 'creature',
#        'creatures', 'credit', 'creepi', 'crew', 'cri', 'crim', 'crime',
#        'crimefight', 'crimeprison', 'crimes', 'crimin', 'criminal',
#        'criminals', 'crisi', 'crisis', 'critic', 'crocodil', 'crook',
#        'cross', 'crowd', 'crown', 'cruel', 'cruelti', 'cruis', 'crusad',
#        'crush', 'crystal', 'cuba', 'cubagoodingjr', 'culmin', 'cult',
#        'cultfilm', 'cultur', 'culture', 'cultureclash', 'cun', 'cup',
#        'cure', 'current', 'curs', 'curse', 'custodi', 'custom', 'cut',
#        'cuttingthecord', 'cyberpunk', 'cyborg', 'cynic', 'dad', 'daili',
#        'damag', 'dan', 'danaykroyd', 'danc', 'dancer', 'danger',
#        'danhedaya', 'daniel', 'danielcraig', 'danni', 'danny',
#        'dannydevito', 'dannyglov', 'dannyhuston', 'dannymcbrid',
#        'dannytrejo', 'dare', 'dark', 'darkcomedi', 'darkest', 'darkness',
#        'darylhannah', 'dash', 'date', 'daughter', 'daughters', 'dave',
#        'davefranco', 'davi', 'david', 'davidcross', 'davidkoechn',
#        'davidmors', 'davidogdensti', 'davidpaym', 'davidspad',
#        'davidstrathairn', 'davidthewli', 'dawn', 'day', 'daydream',
#        'days', 'dc', 'dccomic', 'dea', 'dead', 'deadli', 'deaf', 'deal',
#        'dealer', 'dean', 'death', 'deathofafriend', 'deathpenalti',
#        'deborahkaraung', 'debramess', 'debt', 'debut', 'decad', 'decapit',
#        'deceas', 'deceit', 'decept', 'decid', 'decis', 'declar', 'dedic',
#        'deed', 'deep', 'deeper', 'deepli', 'defeat', 'defend', 'defens',
#        'defi', 'defin', 'deforestkelley', 'delight', 'deliv', 'deliveri',
#        'delroylindo', 'delus', 'demand', 'demimoor', 'demon',
#        'demonicpossess', 'demons', 'deni', 'deniserichard', 'denisleari',
#        'deniso', 'denni', 'dennisfarina', 'dennishopp', 'dennisquaid',
#        'dentist', 'depart', 'depend', 'depict', 'depress', 'depth',
#        'deputi', 'derang', 'derek', 'derekluk', 'dermotmulroney',
#        'descend', 'describ', 'desert', 'design', 'desir', 'desk', 'desol',
#        'despair', 'desper', 'despit', 'destin', 'destini', 'destiny',
#        'destroy', 'destroyed', 'destruct', 'destruction', 'detect',
#        'detective', 'determin', 'detroit', 'devast', 'develop', 'devic',
#        'devil', 'deviou', 'devis', 'devot', 'diabol', 'diagnos',
#        'diamond', 'dian', 'dianekeaton', 'dianekrug', 'dianelan',
#        'diannewiest', 'diari', 'dick', 'dictat', 'did', 'didn', 'die',
#        'died', 'diego', 'diegoluna', 'dies', 'differ', 'different',
#        'difficult', 'dig', 'diner', 'dinner', 'dinosaur', 'diplomat',
#        'dire', 'direct', 'director', 'dirt', 'dirti', 'dirtycop',
#        'disappear', 'disappears', 'disast', 'disaster', 'disastr',
#        'discov', 'discoveri', 'diseas', 'disease', 'disfigur', 'disgrac',
#        'disguis', 'disillus', 'disney', 'disord', 'dispatch', 'disrupt',
#        'distant', 'district', 'disturb', 'ditch', 'diva', 'divid',
#        'divis', 'divorc', 'divorce', 'dj', 'djimonhouns', 'dna', 'doc',
#        'doctor', 'document', 'documentari', 'documentary', 'dodg', 'doe',
#        'doesn', 'dog', 'doll', 'dollar', 'dolphin', 'domest',
#        'domhnallgleeson', 'domin', 'dominiccoop', 'dominicwest', 'don',
#        'donaldfaison', 'donaldsutherland', 'donallogu', 'doncheadl',
#        'donnel', 'doom', 'door', 'dorothi', 'doubl', 'double',
#        'doublecross', 'doubt', 'doug', 'dougrayscott', 'dr', 'dracula',
#        'drag', 'dragon', 'drama', 'dramaamericanfootbal',
#        'dramabasedonnovel', 'dramabiographi', 'dramablackpeopl',
#        'dramabrotherbrotherrelationship', 'dramachristian',
#        'dramafathersonrelationship', 'dramagay', 'dramaindependentfilm',
#        'dramanewyork', 'dramaprison', 'dramarap', 'dramasex',
#        'dramasport', 'dramasuicid', 'dramat', 'draw', 'drawn', 'dread',
#        'dream', 'dreams', 'dress', 'drew', 'drewbarrymor', 'drift',
#        'drifter', 'drink', 'drive', 'driven', 'driver', 'drone', 'drop',
#        'drown', 'drug', 'drugabus', 'drugaddict', 'drugdeal', 'drugs',
#        'drugsmuggl', 'drugtraff', 'drugus', 'drunk', 'drunken', 'du',
#        'dualident', 'dub', 'dude', 'duel', 'duke', 'dump', 'duo', 'dure',
#        'duringcreditssting', 'dustinhoffman', 'dutch', 'duti', 'dutton',
#        'dyinganddeath', 'dylan', 'dylanbak', 'dylanmcdermott', 'dynam',
#        'dynasti', 'dysfunctionalfamili', 'dystopia', 'dystopicfutur',
#        'eager', 'earli', 'earlier', 'earn', 'earth', 'earthquak', 'easi',
#        'easili', 'east', 'eat', 'eccentr', 'econom', 'economi', 'eddi',
#        'eddiemurphi', 'edg', 'edgar', 'edharri', 'edhelm', 'editor',
#        'educ', 'edward', 'edwardburn', 'edwardnorton', 'effect', 'effort',
#        'egg', 'ego', 'egypt', 'egyptian', 'el', 'elabor', 'elderli',
#        'elect', 'element', 'eleph', 'elev', 'eliaskotea', 'elimin',
#        'eliroth', 'elisabethshu', 'elit', 'elite', 'elizabeth',
#        'elizabethbank', 'elizabethperkin', 'ella', 'ellenbarkin',
#        'ellenburstyn', 'elli', 'elliot', 'elliott', 'els', 'elud', 'elus',
#        'elv', 'elvi', 'embark', 'embassi', 'embethdavidtz', 'embroil',
#        'emerg', 'emili', 'emilyblunt', 'emilymortim', 'emilywatson',
#        'emma', 'emmaston', 'emmathompson', 'emmawatson', 'emmetwalsh',
#        'emot', 'emperor', 'empir', 'empire', 'employ', 'employe',
#        'employer', 'enabl', 'enchant', 'encount', 'encourag', 'end',
#        'endless', 'endoftheworld', 'endur', 'enemi', 'enemies', 'enemy',
#        'energi', 'enforc', 'engag', 'engin', 'england', 'english',
#        'enigmat', 'enjoy', 'enlist', 'enorm', 'enrol', 'ensemblecast',
#        'ensu', 'ensues', 'ensur', 'entangl', 'enter', 'enterpris',
#        'entertain', 'enthusiast', 'entir', 'entiti', 'environ',
#        'environment', 'epic', 'epidem', 'episod', 'equal', 'era', 'eric',
#        'ericbana', 'ericrobert', 'erin', 'ernest', 'erotic', 'erupt',
#        'escap', 'escapad', 'escape', 'escapefromprison', 'escort',
#        'especi', 'espionag', 'establish', 'estat', 'estrang', 'etern',
#        'ethan', 'ethancoen', 'ethanhawk', 'ethic', 'eugenelevi', 'europ',
#        'european', 'eva', 'evacu', 'evad', 'evamend', 'evanrachelwood',
#        'eve', 'event', 'events', 'eventu', 'eventually', 'everi',
#        'everybodi', 'everyday', 'everyon', 'everyth', 'evid', 'evil',
#        'evolut', 'evolv', 'ewanmcgregor', 'ex', 'exact', 'exactli',
#        'exam', 'examin', 'exchang', 'excit', 'exclus', 'execut',
#        'exercis', 'exhibit', 'exist', 'existence', 'exorc', 'exot',
#        'exoticisland', 'expect', 'expected', 'expedit', 'experi',
#        'experienc', 'experience', 'experiment', 'expert', 'explain',
#        'explod', 'exploit', 'explor', 'explos', 'expos', 'extend',
#        'extra', 'extramaritalaffair', 'extraordinari', 'extraterrestri',
#        'extraterrestrialtechnolog', 'extrem', 'extremeviol', 'eye',
#        'eyes', 'fabl', 'fac', 'face', 'facil', 'fact', 'faction',
#        'factori', 'fade', 'fail', 'fairi', 'fairytal', 'faith', 'fake',
#        'fall', 'fallen', 'fallinginlov', 'fals', 'falseident',
#        'falselyaccus', 'fame', 'famili', 'families', 'family',
#        'familyfathersonrelationship', 'familyholiday',
#        'familyrelationship', 'famkejanssen', 'famou', 'famous', 'fan',
#        'fans', 'fantasi', 'fantast', 'fantasyworld', 'far', 'farm',
#        'farmer', 'fascin', 'fashion', 'fast', 'faster', 'fat', 'fatal',
#        'fate', 'father', 'fatherdaughterrelationship',
#        'fathersonrelationship', 'favor', 'favorit', 'fbi', 'fbiagent',
#        'fear', 'fearless', 'fearsom', 'featur', 'fed', 'feder', 'feed',
#        'feel', 'feet', 'fellow', 'femal', 'female', 'femalefriendship',
#        'femalenud', 'femaleprotagonist', 'fend', 'festiv', 'festival',
#        'fetish', 'feud', 'fi', 'fiance', 'fiancé', 'fiction', 'field',
#        'fierc', 'fifth', 'fight', 'fighter', 'figur', 'fil', 'file',
#        'film', 'filmdirector', 'filmmak', 'filmproduc', 'films', 'final',
#        'finale', 'financ', 'financi', 'fine', 'finish', 'finn', 'firemen',
#        'firework', 'firm', 'fish', 'fisherman', 'fistfight', 'fit', 'fix',
#        'flame', 'flash', 'flashback', 'flat', 'fledgl', 'flee', 'flesh',
#        'fli', 'flight', 'fling', 'flint', 'flirt', 'flood', 'florida',
#        'florist', 'flower', 'flyingsauc', 'focu', 'focus', 'foe', 'foil',
#        'foley', 'folk', 'follow', 'food', 'foot', 'footag', 'footbal',
#        'footchas', 'forbidden', 'forbiddenlov', 'forc', 'force', 'forces',
#        'ford', 'foreign', 'forest', 'forestwhitak', 'forev', 'forever',
#        'forg', 'forget', 'forgiv', 'form', 'formid', 'formula', 'fort',
#        'fortun', 'fortune', 'forward', 'foster', 'fought', 'foundfootag',
#        'fourth', 'fox', 'frame', 'franc', 'france', 'francesfish',
#        'francesmcdormand', 'francisco', 'frank', 'frankenstein', 'franki',
#        'franklangella', 'frantic', 'fratern', 'fraud', 'freak', 'fred',
#        'freddi', 'fredward', 'free', 'freedom', 'freeman', 'freez',
#        'french', 'frequent', 'fresh', 'freshman', 'friend', 'friendli',
#        'friends', 'friendship', 'frighten', 'frog', 'frontier', 'frozen',
#        'frustrat', 'fu', 'fuel', 'fugit', 'fulfil', 'fulli', 'fun',
#        'fund', 'funer', 'funeral', 'furiou', 'futur', 'future',
#        'futurist', 'fword', 'ga', 'gabriel', 'gabrielbyrn',
#        'gabrielleunion', 'gabrielmacht', 'gadget', 'gain', 'galaxi',
#        'galaxy', 'gambl', 'gambler', 'game', 'games', 'gandhi', 'gang',
#        'gangs', 'gangster', 'garag', 'garden', 'gari', 'garretthedlund',
#        'garycol', 'garygray', 'garyoldman', 'garysinis', 'gasstat',
#        'gate', 'gather', 'gave', 'gay', 'gemmaarterton', 'genehackman',
#        'gener', 'general', 'generation', 'genet', 'geniu', 'genius',
#        'gentl', 'geoffreyrush', 'georg', 'george', 'georgeclooney',
#        'georgetakei', 'georgew', 'georgia', 'gerardbutl', 'german',
#        'germani', 'germany', 'getaway', 'ghetto', 'ghost',
#        'giancarloesposito', 'giant', 'giantrobot', 'gift', 'gig',
#        'giovanniribisi', 'girl', 'girlfriend', 'girls', 'given', 'glamor',
#        'glass', 'glennclos', 'glenneheadli', 'global', 'globe', 'glori',
#        'goal', 'god', 'goe', 'gold', 'golden', 'golf', 'gone', 'good',
#        'goodvsevil', 'goranvisnj', 'gordon', 'gore', 'gorgeou', 'gossip',
#        'got', 'gotham', 'gothamc', 'gotten', 'govern', 'government',
#        'governor', 'gr', 'grace', 'grad', 'grade', 'gradual', 'graduat',
#        'graham', 'grand', 'grandfath', 'grandfather', 'grandmoth',
#        'grandmother', 'grant', 'graphic', 'grave', 'great', 'greater',
#        'greatest', 'greec', 'greed', 'greedi', 'greek', 'green', 'greg',
#        'gregghenri', 'gregkinnear', 'grew', 'grief', 'griev', 'griffin',
#        'grim', 'grip', 'grisli', 'ground', 'group', 'groupoffriend',
#        'grow', 'grown', 'gruesom', 'gu', 'guard', 'guardian', 'guerrilla',
#        'guest', 'guid', 'guilt', 'guitar', 'gun', 'gunfight', 'gunman',
#        'guru', 'guy', 'guypearc', 'guys', 'gwynethpaltrow', 'gym',
#        'gérarddepardieu', 'ha', 'hack', 'hacker', 'hair', 'hal', 'half',
#        'halholbrook', 'hall', 'halleberri', 'halloween', 'hallucin',
#        'han', 'hand', 'handl', 'hands', 'handsom', 'hang', 'hankazaria',
#        'hannah', 'hansel', 'happen', 'happi', 'happili', 'happiness',
#        'happy', 'har', 'hara', 'harass', 'harbor', 'hard', 'harlem',
#        'harmoni', 'harold', 'harri', 'harriet', 'harrison',
#        'harrisonford', 'harrow', 'harry', 'harryconnickjr',
#        'harrydeanstanton', 'harsh', 'hart', 'harvard', 'harvey',
#        'harveykeitel', 'hasn', 'hatch', 'hate', 'hatr', 'haunt',
#        'hauntedhous', 'haven', 'havoc', 'hawaii', 'haydenchristensen',
#        'haydenpanettier', 'haze', 'head', 'headlin', 'heal', 'health',
#        'hear', 'heard', 'heart', 'heartbreak', 'heat', 'heather',
#        'heathergraham', 'heaven', 'heavi', 'heavili', 'heavymet',
#        'height', 'heir', 'heiress', 'heist', 'held', 'helen',
#        'helenabonhamcart', 'helenhunt', 'helenmirren', 'helicopt', 'hell',
#        'help', 'henri', 'henson', 'hero', 'heroes', 'heroic', 'heroin',
#        'heroism', 'hi', 'hidden', 'hide', 'high', 'higher', 'highest',
#        'highland', 'highli', 'highschool', 'highschoolsport',
#        'highschoolstud', 'highway', 'hijack', 'hike', 'hilari', 'hill',
#        'hip', 'hire', 'hiroyukitagawa', 'histor', 'histori',
#        'historicalfigur', 'history', 'hit', 'hitch', 'hitchhik', 'hitman',
#        'ho', 'hobbit', 'hockey', 'hold', 'hole', 'holi', 'holiday',
#        'hollyhunt', 'hollywood', 'home', 'homeinvas', 'homeland',
#        'homeless', 'homelessperson', 'hometown', 'homicid', 'homophobia',
#        'homosexu', 'honey', 'honeymoon', 'hong', 'honor', 'hood',
#        'hoodlum', 'hook', 'hop', 'hope', 'hopedavi', 'hopelessli',
#        'hopper', 'hord', 'horribl', 'horrif', 'horrifi', 'horror', 'hors',
#        'horsebackrid', 'hospit', 'hospital', 'host', 'hostag', 'hostage',
#        'hostil', 'hot', 'hotel', 'hotelroom', 'hotshot', 'hour', 'hous',
#        'house', 'household', 'housewif', 'howard', 'howev', 'hud', 'huge',
#        'hugh', 'hughgrant', 'hughjackman', 'hughlauri', 'hugoweav',
#        'human', 'humanity', 'humankind', 'humans', 'humili', 'humor',
#        'hundr', 'hunger', 'hungri', 'hunt', 'hunter', 'hunters',
#        'hurrican', 'hurt', 'husband', 'hustler', 'hypnosi', 'hypnot',
#        'hyster', 'hyun', 'héctorelizondo', 'ianholm', 'ianmckellen',
#        'ianmcshan', 'ice', 'icecub', 'icon', 'idea', 'ideal', 'idealist',
#        'ident', 'identity', 'idol', 'idriselba', 'idyl', 'ignit', 'ignor',
#        'ii', 'iii', 'il', 'ill', 'illeg', 'illegaldrug', 'illegalimmigr',
#        'illegalprostitut', 'illness', 'illustr', 'imag', 'imagin',
#        'imaginari', 'imagined', 'imax', 'imeldastaunton', 'immedi',
#        'immens', 'immigr', 'immort', 'impact', 'imperi', 'imperson',
#        'implic', 'import', 'imposs', 'impostor', 'impress', 'imprison',
#        'inadvert', 'incest', 'incid', 'includ', 'incompet', 'increas',
#        'increasingli', 'incred', 'independ', 'independentfilm', 'indi',
#        'india', 'indian', 'indiana', 'indianlead', 'individu', 'industri',
#        'industry', 'inevit', 'inexplic', 'infam', 'infant', 'infect',
#        'infidel', 'infiltr', 'influenc', 'inform', 'inhabit', 'inherit',
#        'initi', 'inject', 'injur', 'injuri', 'inmat', 'inner', 'innoc',
#        'insan', 'insecur', 'insid', 'insight', 'insist', 'insomnia',
#        'inspector', 'inspir', 'instal', 'instant', 'instantli', 'instead',
#        'instinct', 'institut', 'institution', 'instructor', 'insur',
#        'insurg', 'intellig', 'intend', 'intens', 'intent', 'intergalact',
#        'intern', 'internet', 'interpret', 'interrog', 'intertwin',
#        'interview', 'intim', 'intoler', 'intrigu', 'introduc', 'invad',
#        'invas', 'invent', 'inventor', 'invest', 'investig', 'investigate',
#        'invis', 'invit', 'involv', 'iowa', 'ira', 'iran', 'iraq',
#        'ireland', 'irish', 'iron', 'irrfankhan', 'isaiahwashington',
#        'islafish', 'island', 'isn', 'isol', 'isra', 'israel', 'issu',
#        'itali', 'italian', 'jack', 'jackass', 'jackblack', 'jacki',
#        'jackieearlehaley', 'jackson', 'jacob', 'jacqu',
#        'jadapinkettsmith', 'jade', 'jaicourtney', 'jail', 'jake',
#        'jakegyllenha', 'jamaica', 'jame', 'james', 'jamesbrolin',
#        'jamescaan', 'jamescromwel', 'jamesdoohan', 'jamesfranco',
#        'jamesgandolfini', 'jamesmarsden', 'jamesmcavoy', 'jamesremar',
#        'jameswood', 'jami', 'jamie', 'jamiefoxx', 'jamieleecurti', 'jan',
#        'jane', 'janelynch', 'janitor', 'japan', 'japanes', 'jaredleto',
#        'jason', 'jasonbateman', 'jasonisaac', 'jasonle', 'jasonmew',
#        'jasonschwartzman', 'jasonsegel', 'jasonstatham', 'jasonsudeiki',
#        'jay', 'jaybaruchel', 'jazz', 'jealousi', 'jean', 'jeanreno',
#        'jedi', 'jeff', 'jeffbridg', 'jeffdaniel', 'jeffgoldblum',
#        'jeffreytambor', 'jeffreywright', 'jenamalon', 'jennif',
#        'jenniferaniston', 'jenniferconnelli', 'jennifercoolidg',
#        'jennifergarn', 'jenniferjasonleigh', 'jenniferlawr',
#        'jenniferlopez', 'jennifertilli', 'jeremyiron', 'jeremynortham',
#        'jeremypiven', 'jeremyrenn', 'jeremysisto', 'jerri', 'jersey',
#        'jerusalem', 'jess', 'jessica', 'jessicaalba', 'jessicabiel',
#        'jessicachastain', 'jessicalang', 'jesu', 'jesus', 'jew', 'jewel',
#        'jewish', 'jigsaw', 'jill', 'jim', 'jimbelushi', 'jimbroadb',
#        'jimcaviezel', 'jimmi', 'jimmy', 'jin', 'joanallen', 'joancusack',
#        'joaquinphoenix', 'job', 'jock', 'jodiefost', 'joe', 'joel',
#        'joeledgerton', 'joemorton', 'joepantoliano', 'joepesci', 'joey',
#        'john', 'johnc', 'johnclees', 'johncusack', 'johngoodman',
#        'johnhannah', 'johnhawk', 'johnheard', 'johnhurt', 'johnkrasinski',
#        'johnleguizamo', 'johnlithgow', 'johnmalkovich', 'johnni',
#        'johnny', 'johnnydepp', 'johnrhys', 'johnson', 'johntravolta',
#        'johnturturro', 'join', 'jon', 'jonahhil', 'jonathan',
#        'jonathanpryc', 'jonathanrhysmey', 'jone', 'jones', 'jonfavreau',
#        'jonvoight', 'jordan', 'joseph', 'josephfienn', 'josephgordon',
#        'josh', 'joshbrolin', 'joshhartnett', 'joshhutcherson', 'joshluca',
#        'joshpeck', 'journal', 'journalist', 'journey', 'joy', 'joybryant',
#        'jr', 'juan', 'judelaw', 'judg', 'judidench', 'judygr', 'juli',
#        'julia', 'julian', 'juliannemoor', 'juliarobert', 'juliastil',
#        'julie', 'julieandrew', 'juliettelewi', 'juliewalt', 'jump',
#        'jungl', 'jungle', 'junior', 'junki', 'just', 'justic', 'justice',
#        'justinlong', 'justintimberlak', 'kansa', 'karat', 'karen',
#        'karlurban', 'kat', 'katden', 'kate', 'katebeckinsal',
#        'katebosworth', 'katehudson', 'katemara', 'katewinslet',
#        'katherin', 'katherineheigl', 'kathi', 'kathrynhahn', 'kathyb',
#        'kati', 'katieholm', 'katniss', 'kay', 'keanureev', 'keef',
#        'keiraknightley', 'keithdavid', 'kelli', 'kelly', 'kellypreston',
#        'kelseygramm', 'ken', 'kenjeong', 'kerirussel', 'kermit',
#        'kerrywashington', 'kevin', 'kevinbacon', 'kevinhart', 'kevinjam',
#        'kevinklin', 'kevinpollak', 'kevinsmith', 'kevinspacey', 'key',
#        'kgb', 'khan', 'kick', 'kid', 'kidnap', 'kidnapp', 'kidnapped',
#        'kids', 'kidsandfamili', 'kiefersutherland', 'kill', 'killed',
#        'killer', 'killerrobot', 'killers', 'kim', 'kimbasing',
#        'kimcattral', 'kind', 'king', 'kingdom', 'kingpin', 'kirk',
#        'kirstendunst', 'kiss', 'kit', 'kitchen', 'knew', 'knife',
#        'knight', 'knit', 'knock', 'know', 'knowledg', 'known', 'kong',
#        'korean', 'kowalski', 'kriskristofferson', 'kristenbel',
#        'kristenstewart', 'kristenwiig', 'kristinscottthoma', 'krueger',
#        'kung', 'kungfu', 'kurt', 'kyle', 'kyrasedgwick', 'la', 'lab',
#        'labor', 'laboratori', 'lac', 'lack', 'ladi', 'ladies', 'ladykil',
#        'laid', 'lake', 'lakebel', 'lanawachowski', 'lancehenriksen',
#        'land', 'landscap', 'lane', 'languag', 'lapd', 'larg', 'larger',
#        'largest', 'larri', 'larrymil', 'laser', 'lasergun', 'lasvega',
#        'late', 'later', 'latest', 'laugh', 'launch', 'laura',
#        'lauralinney', 'laurencefishburn', 'laurengraham', 'lavish', 'law',
#        'lawman', 'lawrenc', 'lawyer', 'lay', 'lazi', 'le', 'lead',
#        'leader', 'leadership', 'leagu', 'learn', 'leav', 'led', 'lee',
#        'leeermey', 'left', 'leg', 'legaci', 'legacy', 'legal', 'legend',
#        'legendari', 'legends', 'legion', 'lena', 'lenaheadey', 'lenaolin',
#        'length', 'lenniejam', 'leo', 'leon', 'leonardnimoy', 'lesbian',
#        'lesliebibb', 'lesliemann', 'leslienielsen', 'lesson', 'let',
#        'lethal', 'letter', 'level', 'levitt', 'lewi', 'lgbt', 'li',
#        'liaison', 'liamneeson', 'liar', 'liber', 'lie', 'lieuten',
#        'lievschreib', 'lif', 'life', 'lifelong', 'lifestyl', 'lifetim',
#        'lift', 'light', 'lightn', 'lik', 'like', 'lil', 'lili', 'limit',
#        'lincoln', 'linda', 'line', 'lines', 'link', 'lion', 'lisa',
#        'lisakudrow', 'list', 'listen', 'liter', 'literatur', 'littl',
#        'littleboy', 'live', 'lives', 'living', 'livtyl', 'lizzi', 'll',
#        'llcoolj', 'lloyd', 'lo', 'loan', 'local', 'locat', 'lock',
#        'logan', 'loganlerman', 'lola', 'lolitadavidovich', 'london',
#        'londonengland', 'lone', 'loneli', 'loner', 'lonewolf', 'long',
#        'longer', 'longtim', 'look', 'loos', 'loose', 'loot', 'lord',
#        'losangel', 'lose', 'loser', 'loss', 'lossofbroth', 'lossofchild',
#        'lossoffamili', 'lossoffath', 'lossofhusband', 'lossoflov',
#        'lossofmoth', 'lost', 'lot', 'lou', 'loui', 'louisepark',
#        'louisiana', 'lov', 'lovabl', 'love', 'loveatfirstsight',
#        'loveless', 'lovelett', 'loveofone', 'lover', 'loves', 'lovesick',
#        'low', 'loyal', 'loyalti', 'lt', 'luca', 'lucasblack', 'luci',
#        'luck', 'lucki', 'lucy', 'lucyliu', 'luisguzmán', 'luke',
#        'lukewilson', 'lure', 'lurk', 'lust', 'luxuri', 'lynn', 'ma',
#        'machin', 'machine', 'machinegun', 'maci', 'mad', 'madam', 'madea',
#        'madison', 'madness', 'mafia', 'magazin', 'maggi', 'maggie',
#        'maggiegyllenha', 'maggiesmith', 'magic', 'magician', 'maid',
#        'mail', 'main', 'maintain', 'major', 'mak', 'make', 'mako',
#        'malcolm', 'malcolmmcdowel', 'male', 'malefemalerelationship',
#        'malefriendship', 'malinåkerman', 'mall', 'malley', 'man', 'manag',
#        'manager', 'mandymoor', 'manhattan', 'manhunt', 'mani', 'maniac',
#        'manipul', 'mankind', 'mann', 'manner', 'mansion', 'manufactur',
#        'manvsmachin', 'map', 'mar', 'march', 'marciagayharden', 'marcu',
#        'mari', 'maria', 'mariabello', 'marie', 'marijuana', 'marin',
#        'marioncotillard', 'marisatomei', 'mark', 'markduplass', 'market',
#        'markruffalo', 'markstrong', 'markwahlberg', 'marri', 'marriag',
#        'marriage', 'marriagecrisi', 'marriagepropos', 'married',
#        'marriedcoupl', 'marsh', 'marshal', 'martha', 'marti', 'martial',
#        'martialart', 'martian', 'martin', 'martinlandau', 'martinsheen',
#        'martoncsoka', 'marvelcinematicunivers', 'marvelcom', 'mary',
#        'maryelizabethwinstead', 'marykayplac', 'marymccormack',
#        'marysteenburgen', 'mask', 'mass', 'massacr', 'massiv', 'massmurd',
#        'master', 'mastermind', 'match', 'mate', 'materi', 'mathemat',
#        'matrix', 'matt', 'mattdamon', 'mattdillon', 'matter',
#        'matteroflifeanddeath', 'matthew', 'matthewbroderick',
#        'matthewgood', 'matthewlillard', 'matthewmcconaughey',
#        'maurychaykin', 'maverick', 'max', 'maxvonsydow', 'maya',
#        'mayarudolph', 'mayb', 'mayhem', 'mayor', 'maze', 'mccall',
#        'mcclane', 'mcginley', 'meagangood', 'mean', 'meant', 'meanwhil',
#        'meat', 'mechan', 'medallion', 'media', 'medic', 'medicin',
#        'mediev', 'meet', 'mega', 'megan', 'meganfox', 'mekhiphif',
#        'melanielynskey', 'melgibson', 'melissa', 'melissaleo', 'melvin',
#        'member', 'members', 'memoir', 'memori', 'men', 'menac',
#        'menasuvari', 'mental', 'mentor', 'mercenari', 'merchant',
#        'merciless', 'mere', 'mermaid', 'merylstreep', 'messag', 'met',
#        'metal', 'meteor', 'method', 'metro', 'mexican', 'mexicanstandoff',
#        'mexico', 'mia', 'miami', 'michael', 'michaelangarano',
#        'michaelbiehn', 'michaelcain', 'michaelclarkeduncan',
#        'michaeleali', 'michaelfassbend', 'michaelgambon', 'michaelj',
#        'michaeljaiwhit', 'michaeljet', 'michaelkeaton', 'michaelmadsen',
#        'michaelpeña', 'michaelrapaport', 'michaelrook', 'michaelshannon',
#        'michaelsheen', 'michaelwincott', 'michel', 'michellemonaghan',
#        'michellepfeiff', 'michellerodriguez', 'michellewilliam',
#        'michigan', 'mickey', 'mickeyrourk', 'mid', 'middl', 'middle',
#        'middleag', 'middleeast', 'midlifecrisi', 'midnight', 'midst',
#        'midwest', 'mighti', 'mike', 'mikeepp', 'milakuni', 'mild', 'mile',
#        'militari', 'miller', 'million', 'millionair', 'mind', 'miner',
#        'minist', 'minniedriv', 'minor', 'minut', 'miracl', 'miracul',
#        'mirandarichardson', 'mirror', 'misadventur', 'misanthrop',
#        'mischiev', 'miser', 'misfit', 'mismatch', 'miss', 'missil',
#        'missing', 'mission', 'missionofmurd', 'mississippi', 'mistak',
#        'mistaken', 'mistakenident', 'mistakenli', 'mistress', 'mitch',
#        'mitchel', 'mix', 'mob', 'mobster', 'mockumentari', 'model',
#        'modern', 'mole', 'molli', 'mom', 'moment', 'money', 'monica',
#        'monk', 'monkey', 'monster', 'monsters', 'monstrou', 'montana',
#        'month', 'months', 'montreal', 'moon', 'moonlight', 'moor',
#        'moore', 'moral', 'morgan', 'morganfreeman', 'morgu', 'mormon',
#        'morn', 'morrischestnut', 'mortal', 'moscow', 'mossad', 'mostli',
#        'motel', 'mother', 'motherdaughterrelationship', 'motherrol',
#        'mothersonrelationship', 'motion', 'motiv', 'motley', 'motor',
#        'motorcycl', 'mount', 'mountain', 'mountains', 'mous', 'mouth',
#        'movement', 'movi', 'movie', 'movieinmovi', 'movies', 'moviestar',
#        'mr', 'multi', 'multipl', 'murder', 'murdered', 'murderer',
#        'murphi', 'murray', 'mus', 'museum', 'music', 'musician',
#        'musicmus', 'musket', 'muslim', 'mut', 'mutant', 'mutat', 'mutini',
#        'mutual', 'mysteri', 'mystery', 'mystic', 'mythic', 'mytholog',
#        'naiv', 'nam', 'nanni', 'naomiwatt', 'narcot', 'narrat', 'nasa',
#        'nasti', 'natalieportman', 'nathan', 'nathanlan', 'nation',
#        'nativ', 'nativeamerican', 'natur', 'nature', 'navi', 'navig',
#        'navys', 'nazi', 'nazigermani', 'nba', 'near', 'nearbi', 'nearli',
#        'necessari', 'nedbeatti', 'need', 'nefari', 'negoti', 'neighbor',
#        'neighborhood', 'neil', 'neilpatrickharri', 'nelson', 'nemesi',
#        'nemesis', 'neo', 'nephew', 'nerd', 'nerdi', 'network', 'nevada',
#        'nevecampbel', 'new', 'newborn', 'newcom', 'newfound', 'newident',
#        'newli', 'newlov', 'newlyw', 'news', 'newspap', 'newyork',
#        'newyorkc', 'nialong', 'nice', 'nicholashoult', 'nick',
#        'nickfrost', 'nicknolt', 'nickswardson', 'nicol', 'nicolascag',
#        'nicolekidman', 'niec', 'niece', 'night', 'nightclub', 'nightmar',
#        'nightmare', 'nightshyamalan', 'nightstand', 'ninja', 'noah',
#        'noahemmerich', 'nobl', 'nobodi', 'noir', 'non', 'normal',
#        'norman', 'north', 'northern', 'nose', 'note', 'noth', 'notic',
#        'notori', 'novel', 'novelist', 'nowher', 'nuclear',
#        'nuclearmissil', 'nuditi', 'number', 'numer', 'nun', 'nurs',
#        'nypd', 'object', 'observ', 'obsess', 'obsession', 'obstacl',
#        'obtain', 'occult', 'occupi', 'occur', 'ocean', 'odd', 'oddbal',
#        'odds', 'odedfehr', 'odyssey', 'offer', 'offic', 'office',
#        'officer', 'offici', 'ohio', 'oil', 'old', 'older', 'oliv',
#        'oliverplatt', 'olivia', 'oliviawild', 'oliviawilliam', 'olymp',
#        'olympicgam', 'omar', 'onc', 'onli', 'onlin', 'onofrio',
#        'ontherun', 'open', 'oper', 'opera', 'operation', 'opportun',
#        'oppos', 'opposit', 'oppress', 'orc', 'orchestr', 'order',
#        'ordinari', 'oregon', 'organ', 'organization', 'organizedcrim',
#        'origin', 'orlandobloom', 'orlean', 'orphan', 'orphanag',
#        'orphanage', 'oscar', 'oscaraward', 'oscarisaac', 'otherworldli',
#        'outback', 'outbreak', 'outcast', 'outerspac', 'outlaw', 'outrag',
#        'outsid', 'outwit', 'overcom', 'overrun', 'overthrow', 'overwhelm',
#        'owenwilson', 'owl', 'owner', 'oxford', 'oz', 'pacif', 'pack',
#        'packag', 'pact', 'paddyconsidin', 'pageant', 'paid', 'pain',
#        'paint', 'painter', 'pair', 'pal', 'pam', 'pamgrier', 'pan',
#        'pandora', 'panic', 'paper', 'parallel', 'paranoia', 'paranoid',
#        'paranorm', 'parent', 'parents', 'parentskidsrelationship', 'pari',
#        'paris', 'parisian', 'park', 'parker', 'parkerposey', 'parodi',
#        'parol', 'parrish', 'parti', 'particip', 'particularli', 'parties',
#        'partner', 'partners', 'partnership', 'party', 'pass', 'passeng',
#        'passion', 'past', 'pastor', 'path', 'patient', 'patriarch',
#        'patriciaarquett', 'patriciaclarkson', 'patrick', 'patrickstewart',
#        'patrickwarburton', 'patrickwilson', 'patriot', 'patrol', 'paul',
#        'paulapatton', 'paulbettani', 'pauldano', 'paulgiamatti',
#        'paulrudd', 'paulsorvino', 'pawn', 'pay', 'peac', 'peace', 'pearl',
#        'peasant', 'penguin', 'penn', 'pennsylvania', 'penélopecruz',
#        'peopl', 'people', 'perfect', 'perform', 'perhap', 'peril',
#        'period', 'perioddrama', 'perry', 'persian', 'person', 'persuad',
#        'pet', 'pete', 'petepostlethwait', 'peter', 'peterberg',
#        'peterboyl', 'peterfarrelli', 'petersarsgaard', 'peterstormar',
#        'petti', 'phantom', 'phil', 'philadelphia', 'philipseymourhoffman',
#        'phillip', 'philosoph', 'philosophi', 'phone', 'photo',
#        'photograph', 'photographi', 'physic', 'pianist', 'piano',
#        'picard', 'pick', 'pictur', 'picture', 'piec', 'piercebrosnan',
#        'pierr', 'pierrejeunet', 'pig', 'pilot', 'pimp', 'pink',
#        'pinocchio', 'piperperabo', 'pirat', 'pistol', 'pit', 'pitch',
#        'place', 'plagu', 'plan', 'plane', 'planet', 'plannedmurd',
#        'plans', 'plant', 'plantat', 'plass', 'play', 'playboy', 'player',
#        'playground', 'playwright', 'pleasur', 'plenti', 'plot', 'plung',
#        'po', 'poet', 'poetri', 'point', 'poison', 'poker', 'polar',
#        'polic', 'police', 'policebrut', 'policechas', 'policeman',
#        'policeoffic', 'policeoper', 'polit', 'politician', 'polli',
#        'pool', 'poor', 'pop', 'popul', 'popular', 'porn', 'port',
#        'portal', 'porter', 'portrait', 'portray', 'pose', 'posit',
#        'possess', 'possibl', 'post', 'pot', 'potenti', 'potter', 'pound',
#        'poverti', 'pow', 'power', 'poweroutag', 'powers', 'practic',
#        'prank', 'prayer', 'pre', 'preacher', 'preciou', 'predat',
#        'predict', 'prefer', 'pregnanc', 'pregnancyandbirth', 'pregnant',
#        'prehistor', 'prejudic', 'premonit', 'prepar', 'prequel',
#        'presenc', 'present', 'presid', 'president', 'presidenti',
#        'presidentialelect', 'press', 'pressur', 'presum', 'pretend',
#        'pretti', 'prevent', 'previou', 'prey', 'price', 'priceless',
#        'pride', 'priest', 'prime', 'princ', 'prince', 'princess',
#        'princip', 'principl', 'prison', 'prisonersofwar', 'privat',
#        'privileg', 'prize', 'pro', 'problem', 'problems', 'process',
#        'produc', 'product', 'production', 'profession', 'professor',
#        'profil', 'profit', 'program', 'progress', 'project', 'prom',
#        'promin', 'promis', 'promot', 'prompt', 'promptli', 'proof',
#        'properti', 'propos', 'prosecut', 'prospect', 'prostitut',
#        'protect', 'protest', 'prove', 'provid', 'psychiatr',
#        'psychiatrist', 'psychic', 'psycholog', 'psychologist',
#        'psychopath', 'psychot', 'pub', 'puberti', 'public', 'publish',
#        'pull', 'punish', 'punk', 'puppet', 'puppi', 'purchas', 'pure',
#        'purpos', 'pursu', 'pursuit', 'push', 'quarantin', 'quarterback',
#        'queen', 'queenlatifah', 'quentintarantino', 'quest', 'question',
#        'quick', 'quickli', 'quiet', 'quirki', 'quit', 'rabbit', 'race',
#        'raceagainsttim', 'racer', 'rachaelleighcook', 'rachel',
#        'rachelmcadam', 'rachelweisz', 'racial', 'racism', 'radhamitchel',
#        'radiat', 'radic', 'radio', 'rag', 'rage', 'rageandh', 'ragtag',
#        'raid', 'railroad', 'rain', 'rais', 'ralli', 'ralph', 'ralphfienn',
#        'rampag', 'ran', 'ranch', 'randyquaid', 'ranger', 'rank', 'ransom',
#        'rape', 'rapidli', 'rapper', 'rare', 'rat', 'rate', 'ravag', 'raw',
#        'ray', 'rayliotta', 'raymond', 'raymondj', 'raywinston', 'reach',
#        'reaction', 'read', 'readi', 'real', 'realis', 'realiti',
#        'reality', 'realiz', 'realli', 'realm', 'reaper', 'reason',
#        'rebecca', 'rebel', 'rebelli', 'rebellion', 'reboot', 'rebuild',
#        'receiv', 'recent', 'reckless', 'reclaim', 'reclus', 'reconcil',
#        'reconnect', 'record', 'recount', 'recov', 'recreat', 'recruit',
#        'red', 'redempt', 'redemption', 'rediscov', 'redneck', 'reel',
#        'reesewitherspoon', 'reflect', 'refug', 'refus', 'regain',
#        'regard', 'regim', 'reginahal', 'reginak', 'regret', 'regular',
#        'reign', 'reilli', 'reject', 'rekindl', 'rel', 'relat',
#        'relationship', 'relationshipproblem', 'relationships', 'releas',
#        'relentless', 'reli', 'religi', 'religion',
#        'religionandsupernatur', 'reloc', 'reluct', 'reluctantli',
#        'remain', 'remak', 'remark', 'rememb', 'remind', 'reminisc',
#        'remot', 'renegad', 'renerusso', 'renown', 'rent', 'renéezellweg',
#        'repair', 'repay', 'replac', 'report', 'reporter', 'repres',
#        'repress', 'reput', 'request', 'requir', 'rescu', 'rescue',
#        'research', 'resid', 'resist', 'resistance', 'resolv', 'resort',
#        'resourc', 'resources', 'respect', 'respond', 'respons', 'rest',
#        'restaur', 'restaurant', 'restor', 'result', 'results', 'resurfac',
#        'resurrect', 'retel', 'retir', 'retreat', 'retriev', 'return',
#        'reunion', 'reunit', 'reveal', 'revealed', 'revel', 'reveng',
#        'revenge', 'reviv', 'revolut', 'revolutionari', 'revolv', 'reward',
#        'rhysifan', 'rich', 'richard', 'richarddreyfuss', 'richardger',
#        'richardharri', 'richardjenkin', 'rick', 'ricki', 'rid', 'riddl',
#        'ride', 'rider', 'ridicul', 'rifl', 'rig', 'right',
#        'rightandjustic', 'riley', 'ring', 'riot', 'rip', 'ripley',
#        'riptorn', 'rise', 'risk', 'rival', 'rivalri', 'river', 'road',
#        'roadmovi', 'roadtrip', 'roam', 'roar', 'rob', 'robber', 'robberi',
#        'robbiecoltran', 'robcorddri', 'robert', 'robertcarlyl',
#        'robertdeniro', 'robertdowneyjr', 'robertduval', 'robertforst',
#        'robertloggia', 'robertpatrick', 'robertrodriguez', 'robin',
#        'robinson', 'robinwilliam', 'robinwright', 'robot', 'rock',
#        'rocket', 'rocki', 'rockstar', 'rodrigosantoro', 'rodsteig',
#        'roger', 'rogu', 'role', 'roll', 'roller', 'rom', 'roman',
#        'romanc', 'romance', 'romancebasedonnovel', 'romancedanc',
#        'romancegay', 'romanceindependentfilm', 'romancelondonengland',
#        'romancelovetriangl', 'romancemus', 'romancenewyork',
#        'romancepari', 'romancesex', 'romancesuicid', 'romant',
#        'romanticcomedi', 'rome', 'romeo', 'romero', 'ron',
#        'ronlivingston', 'ronni', 'ronperlman', 'roof', 'rooftop', 'rooki',
#        'room', 'roommat', 'root', 'rosamundpik', 'rosariodawson', 'rose',
#        'rosebyrn', 'ross', 'rough', 'round', 'routin', 'row', 'roy',
#        'royal', 'royalti', 'rufussewel', 'rugrat', 'ruin', 'rule',
#        'rumor', 'run', 'runaway', 'runner', 'rupertgrint', 'rural',
#        'ruralset', 'rush', 'russel', 'russellcrow', 'russia', 'russian',
#        'ruth', 'ruthless', 'ryan', 'ryangosl', 'ryanphillipp',
#        'ryanreynold', 'sabotag', 'sacr', 'sacrific', 'sad', 'sadism',
#        'sadist', 'safe', 'safeti', 'safety', 'saga', 'said', 'sail',
#        'sailor', 'saint', 'sale', 'salesman', 'salli', 'sallyhawkin',
#        'salmahayek', 'sam', 'samantha', 'samanthamorton', 'samelliott',
#        'samneil', 'samrockwel', 'samshepard', 'samuel', 'samuell',
#        'samurai', 'san', 'sand', 'sandi', 'sandrabullock', 'sanfrancisco',
#        'santa', 'santaclau', 'sara', 'sarah', 'sarahjessicapark',
#        'sarahmichellegellar', 'sarapaxton', 'satan', 'satellit', 'satir',
#        'satisfi', 'savag', 'save', 'saw', 'say', 'sbook', 'scam',
#        'scandal', 'scar', 'scare', 'scari', 'scarlettjohansson', 'scene',
#        'schedul', 'scheme', 'scholarship', 'school', 'schoolteach', 'sci',
#        'scienc', 'sciencefict', 'sciencefictionandroid',
#        'sciencefictionbasedonnovel', 'sciencefictionmonst',
#        'sciencefictionsavingtheworld', 'scientif', 'scientist', 'score',
#        'scotland', 'scott', 'scottglenn', 'scottish', 'scottport',
#        'scottspeedman', 'scout', 'scrambl', 'scream', 'screen',
#        'screenwrit', 'script', 'scubadiv', 'sdailylif', 'sea', 'seal',
#        'sean', 'seanbean', 'seanconneri', 'seannwilliamscott', 'seanpenn',
#        'search', 'seas', 'seasid', 'season', 'sebastian', 'seclud',
#        'second', 'secret', 'secretag', 'secretari', 'secretident',
#        'secretintelligenceservic', 'secretli', 'secretlov', 'secretmiss',
#        'secretorgan', 'secrets', 'secretservic', 'secretsocieti',
#        'section', 'secur', 'securityguard', 'seduc', 'seduct', 'seek',
#        'seemingli', 'seen', 'seiz', 'sel', 'self', 'selfsacrific', 'sell',
#        'selmablair', 'semi', 'senat', 'send', 'senior', 'sens', 'sensat',
#        'sensit', 'sent', 'sentenc', 'seo', 'separ', 'sequel', 'sergeant',
#        'seri', 'serial', 'serialkil', 'series', 'seriou', 'seriously',
#        'serv', 'servant', 'servic', 'service', 'session', 'set', 'seth',
#        'sethgreen', 'sethrogen', 'settl', 'settler', 'sev', 'seven',
#        'sever', 'sewer', 'sex', 'sexi', 'sexual', 'sexualabus', 'shadi',
#        'shadow', 'shadowi', 'shake', 'shaken', 'shakespeare', 'shane',
#        'shanghai', 'shape', 'share', 'shark', 'sharonston', 'sharp',
#        'shatter', 'shaw', 'shelter', 'shepherd', 'sheriff', 'shi',
#        'shield', 'shift', 'ship', 'shipwreck', 'shock', 'shoe', 'shoot',
#        'shootout', 'shop', 'short', 'shot', 'shotgun', 'showdown',
#        'shower', 'shredder', 'shrek', 'shut', 'shuttl', 'sibl', 'sick',
#        'sid', 'sidekick', 'sidney', 'sight', 'sign', 'signal',
#        'sigourneyweav', 'silenc', 'silent', 'silver', 'similar', 'simmon',
#        'simon', 'simonpegg', 'simpl', 'simpli', 'simpson', 'simultan',
#        'sin', 'sinc', 'sing', 'singer', 'singl', 'single', 'singlemoth',
#        'singlepar', 'sinist', 'sir', 'sissyspacek', 'sister', 'sisters',
#        'sistersisterrelationship', 'sit', 'site', 'sittingonatoilet',
#        'situat', 'situation', 'size', 'skeetulrich', 'skeleton',
#        'skeptic', 'ski', 'skill', 'skull', 'sky', 'skyscrap', 'slacker',
#        'slasher', 'slaughter', 'slave', 'slaveri', 'slavery', 'sleazi',
#        'sleep', 'sleepi', 'slif', 'slip', 'slowli', 'small', 'smalltown',
#        'smart', 'smash', 'smith', 'smitten', 'smoke', 'smuggl',
#        'smuggler', 'snake', 'snatch', 'sniper', 'snow', 'snowstorm',
#        'soccer', 'social', 'societi', 'society', 'sociopath', 'sofia',
#        'sofíavergara', 'solar', 'sold', 'soldier', 'soldiers', 'sole',
#        'solitari', 'solomon', 'solv', 'somebodi', 'someon', 'someth',
#        'sometim', 'somewhat', 'somewher', 'son', 'song', 'songwrit',
#        'soon', 'sophi', 'sorcer', 'sorcerer', 'sorceri', 'soror', 'sort',
#        'soul', 'sound', 'soundtrack', 'sour', 'south', 'southafrica',
#        'southern', 'southernusa', 'soviet', 'sovietunion', 'space',
#        'spacecraft', 'spacemarin', 'spacemiss', 'spaceopera', 'spaceship',
#        'spacetravel', 'spain', 'span', 'spanish', 'spark', 'speak',
#        'speci', 'special', 'specialist', 'spectacular', 'speech', 'speed',
#        'spell', 'spencer', 'spencerbreslin', 'spend', 'spent', 'spi',
#        'spider', 'spike', 'spikele', 'spin', 'spiral', 'spirit',
#        'spiritu', 'spite', 'spoil', 'spoof', 'sport', 'spot', 'spotlight',
#        'spread', 'spring', 'squad', 'squar', 'st', 'stab', 'stacykeach',
#        'staff', 'stage', 'stahl', 'stak', 'stake', 'stalk', 'stalker',
#        'stan', 'stand', 'stanley', 'stanleytucci', 'star', 'stardom',
#        'starfleet', 'stark', 'start', 'state', 'states', 'station',
#        'statu', 'stay', 'steal', 'steampunk', 'steel', 'stella',
#        'stellanskarsgård', 'step', 'stepfath', 'stephen', 'stephenrea',
#        'stepmoth', 'steve', 'stevebuscemi', 'stevecarel', 'stevemartin',
#        'steven', 'stevezahn', 'stewart', 'stick', 'stir', 'stock',
#        'stockardchan', 'stolen', 'stone', 'stoner', 'stop', 'stopmot',
#        'store', 'stori', 'stories', 'storm', 'story', 'straight',
#        'strain', 'strand', 'strang', 'stranger', 'strateg', 'strategi',
#        'stray', 'street', 'streetgang', 'streets', 'strength', 'stress',
#        'stretch', 'strict', 'strike', 'strikes', 'strip', 'stripclub',
#        'stripper', 'strive', 'strong', 'struggl', 'stu', 'stuart',
#        'stuck', 'student', 'students', 'studi', 'studio', 'stumbl',
#        'stun', 'stunt', 'style', 'su', 'sub', 'subject', 'submachinegun',
#        'submarin', 'subsequ', 'suburban', 'subway', 'succeed', 'success',
#        'successful', 'successor', 'sudden', 'suddenli', 'sue', 'suffer',
#        'suggest', 'suicid', 'suicide', 'suicideattempt', 'suit', 'suitor',
#        'sullivan', 'summer', 'summon', 'sun', 'sunglass', 'super',
#        'superhero', 'superhuman', 'superman', 'supermarket', 'supernatur',
#        'supernaturalpow', 'superpow', 'superstar', 'supervillain',
#        'supervisor', 'suppli', 'support', 'suppos', 'suppress',
#        'suppressedpast', 'sure', 'surf', 'surfac', 'surface', 'surfer',
#        'surgeon', 'surpris', 'surreal', 'surround', 'surveil', 'surviv',
#        'survival', 'survive', 'survivor', 'survivors', 'susan',
#        'susansarandon', 'suspect', 'suspens', 'suspici', 'suspicion',
#        'swallow', 'sweep', 'sweet', 'sweetheart', 'swept', 'swimmingpool',
#        'swing', 'switch', 'sword', 'swordfight', 'swordplay',
#        'sylvesterstallon', 'symbol', 'tabl', 'tabloid', 'tactic', 'tag',
#        'tail', 'tak', 'taken', 'tale', 'talent', 'talk', 'talkinganim',
#        'tall', 'tank', 'tap', 'tape', 'tarajip', 'tarareid', 'target',
#        'task', 'tast', 'tattoo', 'taxi', 'taxidriv', 'tayedigg', 'taylor',
#        'teach', 'teacher', 'team', 'tear', 'tech', 'technolog',
#        'technology', 'ted', 'teen', 'teenag', 'teenagecrush',
#        'teenagegirl', 'teenager', 'teencomedi', 'teenmovi', 'telekinesi',
#        'telepathi', 'teleport', 'televis', 'tell', 'tens', 'tension',
#        'terencestamp', 'teresapalm', 'terigarr', 'teripolo', 'term',
#        'termin', 'terminalil', 'terrencehoward', 'terri', 'terribl',
#        'terrier', 'terrifi', 'territori', 'terror', 'terrorist', 'tess',
#        'test', 'tested', 'texa', 'texas', 'th', 'thailand',
#        'thandienewton', 'thank', 'thanksgiv', 'theater', 'theatremilieu',
#        'theft', 'theme', 'themselv', 'theori', 'therapist', 'thi',
#        'thief', 'thiev', 'thing', 'things', 'think', 'thirst', 'thirti',
#        'thoma', 'thomashadenchurch', 'thomasjan', 'thomaskretschmann',
#        'thompson', 'thought', 'thousand', 'threat', 'threaten', 'thril',
#        'thrill', 'thriller', 'thrillerassassin', 'thrillerbasedonnovel',
#        'thrillerbomb', 'thrillerbrotherbrotherrelationship',
#        'thrillercalifornia', 'thrillercia', 'thrillercorrupt',
#        'thrillerdetect', 'thrillerdystopia', 'thrillerfemalenud',
#        'thrillerlondonengland', 'thrillernewyork', 'thrillerpari',
#        'thrillerprison', 'thrillersheriff', 'thrillersuicid',
#        'thrillerterror', 'throne', 'throw', 'thrown', 'thrust', 'thu',
#        'thug', 'thwart', 'tibet', 'tick', 'ticket', 'tie', 'tiger',
#        'tildaswinton', 'tim', 'timblakenelson', 'timcurri', 'time',
#        'timeless', 'times', 'timetravel', 'timothyhutton', 'timothyolyph',
#        'timothyspal', 'timrobbin', 'timroth', 'tini', 'tire', 'titan',
#        'titl', 'tobeymaguir', 'tobyjon', 'tobykebbel', 'today', 'todd',
#        'togeth', 'tokyo', 'told', 'tom', 'tomfelton', 'tommi',
#        'tommyleejon', 'tomsizemor', 'tomwilkinson', 'toni', 'tonicollett',
#        'tonyshalhoub', 'took', 'tool', 'torment', 'torn', 'tornado',
#        'toronto', 'tortur', 'total', 'touch', 'tough', 'toughest', 'tour',
#        'tourist', 'tournament', 'tower', 'town', 'toxic', 'toy', 'trace',
#        'track', 'trade', 'trader', 'tradit', 'traffic', 'traffick',
#        'tragedi', 'tragedy', 'tragic', 'trail', 'train', 'trainer',
#        'traitor', 'transfer', 'transform', 'transit', 'transplant',
#        'transport', 'trap', 'trauma', 'traumat', 'travel', 'treacher',
#        'treasur', 'treasurehunt', 'treat', 'treatment', 'treatwilliam',
#        'tree', 'trek', 'tri', 'trial', 'triangl', 'triangle', 'tribe',
#        'trick', 'trigger', 'trio', 'trip', 'triumph', 'troop', 'tropic',
#        'troubl', 'trouble', 'troy', 'truck', 'trucker', 'true', 'truli',
#        'trust', 'truth', 'tsunami', 'tunnel', 'turbul', 'turmoil', 'turn',
#        'turned', 'turner', 'turtl', 'tv', 'tvshow', 'tvstation', 'twenti',
#        'twin', 'twinbroth', 'twist', 'tycoon', 'tyler', 'tylerperri',
#        'type', 'typic', 'tyrann', 'tyresegibson', 'téaleoni', 'ufo',
#        'ugli', 'ultim', 'ultra', 'umathurman', 'unabl', 'unawar',
#        'unbeknownst', 'uncl', 'uncle', 'uncomfort', 'unconvent', 'uncov',
#        'undead', 'undercov', 'undercoverag', 'undercovercop', 'underdog',
#        'undergo', 'underground', 'understand', 'undertak', 'underwat',
#        'underworld', 'unemploy', 'unexpect', 'unexpectedli', 'unexplain',
#        'unfaith', 'unfold', 'unforeseen', 'unforgett', 'unfortun',
#        'unfortunately', 'unhappi', 'unimagin', 'union', 'uniqu', 'unit',
#        'univers', 'universe', 'university', 'unknown', 'unleash',
#        'unless', 'unlik', 'unlikelyfriendship', 'unlock', 'unorthodox',
#        'unpreced', 'unpredict', 'unravel', 'unsoci', 'unstabl', 'unstopp',
#        'unsuspect', 'unusu', 'unveil', 'unwit', 'unwittingli', 'upcom',
#        'upper', 'upris', 'upset', 'upsid', 'uptight', 'urban', 'urg',
#        'usa', 'usapresid', 'use', 'usual', 'utah', 'vacat', 'vacation',
#        'val', 'valentine', 'valkilm', 'valley', 'valu', 'valuabl',
#        'vampir', 'vampire', 'vampires', 'van', 'vandal', 'vanessa',
#        'vanessahudgen', 'vanessaredgrav', 'vanish', 'varieti', 'variou',
#        'vast', 'vatican', 'vault', 'vega', 'vegas', 'vegetarian', 'veng',
#        'vengeanc', 'vengeance', 'ventur', 'verafarmiga', 'verg', 'veri',
#        'version', 'vet', 'veteran', 'vice', 'viciou', 'victim', 'victims',
#        'victor', 'victori', 'victoria', 'victorian', 'victory', 'video',
#        'vietnam', 'vietnamwar', 'view', 'viewer', 'viggomortensen',
#        'vigilant', 'vike', 'villag', 'village', 'villain', 'vincent',
#        'vincentcassel', 'vincentd', 'vincevaughn', 'vineyard', 'vingrham',
#        'vinniejon', 'violadavi', 'violenc', 'violence', 'violent',
#        'virgin', 'virginia', 'virginiamadsen', 'virginity', 'virtual',
#        'virtualr', 'viru', 'vision', 'visit', 'visitor', 'visual',
#        'vivicaa', 'vlad', 'voic', 'voice', 'volatil', 'volcano', 'volunt',
#        'vomit', 'von', 'voodoo', 'vow', 'voyag', 'voyeur', 'wa', 'wacki',
#        'wade', 'wage', 'wager', 'wai', 'wait', 'waiter', 'waitress',
#        'wake', 'walk', 'walker', 'wall', 'wallet', 'wallstreet', 'walsh',
#        'walt', 'walter', 'wander', 'wang', 'want', 'war', 'warcrim',
#        'ward', 'warden', 'warehous', 'warhead', 'warlock', 'warlord',
#        'warm', 'warn', 'warondrug', 'warren', 'warrior', 'wars', 'wash',
#        'washington', 'wast', 'watch', 'water', 'wave', 'way', 'ways',
#        'weak', 'wealth', 'wealthi', 'weapon', 'wear', 'weather', 'web',
#        'wed', 'wedding', 'week', 'weekend', 'weird', 'welcom', 'went',
#        'werewolf', 'wesbentley', 'wesley', 'west', 'western',
#        'westerngunsling', 'whale', 'whatev', 'wheelchair', 'whi', 'whip',
#        'whisk', 'whit', 'white', 'whoopigoldberg', 'wick', 'widow',
#        'wield', 'wif', 'wife', 'wifehusbandrelationship', 'wild',
#        'wilder', 'wilderness', 'wildli', 'willarnett', 'willemdafo',
#        'willferrel', 'willi', 'william', 'williamfichtn',
#        'williamforsyth', 'williamh', 'williamhurt', 'williamsadl',
#        'willpatton', 'wilson', 'win', 'wind', 'window', 'wine', 'wing',
#        'winner', 'winonaryd', 'winter', 'wipe', 'wise', 'wish', 'wit',
#        'witch', 'wizard', 'wolf', 'woman', 'womandirector', 'womanrel',
#        'women', 'won', 'wonder', 'woo', 'wood', 'woodi', 'woods',
#        'woodyallen', 'woodyharrelson', 'word', 'work', 'workahol',
#        'worker', 'workers', 'working', 'world', 'worlds', 'worldwari',
#        'worldwarii', 'worldwid', 'worri', 'wors', 'worse', 'worst',
#        'worth', 'wound', 'wreak', 'wrestl', 'wrestler', 'wretch',
#        'wright', 'write', 'writer', 'written', 'wrong', 'wwii', 'yacht',
#        'yakuza', 'yard', 'yasiinbey', 'year', 'yearn', 'years', 'yellow',
#        'york', 'yorker', 'young', 'youngadult', 'youngboy', 'younger',
#        'youngest', 'youngster', 'youth', 'zachgalifianaki', 'zealand',
#        'zeu', 'zhangziyi', 'zion', 'zoe', 'zoesaldana', 'zombi',
#        'zombies', 'zone', 'zoo', 'zooeydeschanel'], dtype=object)

# %% [markdown]
# ## Calculate csosine_similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(vector)

# %% [markdown]
# ## Sort and assign id

# %%
sort = sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])[1:11]

# %% [markdown]
# ## Main function

# %%
def recommend(movie):
    movie_index = df[df["title"]==movie].index[0]
    distance = similarity[movie_index]
    movie_list = sorted(list(enumerate(similarity[movie_index])),reverse=True,key=lambda x:x[1])[1:11]

    for i in movie_list:
        print(df.iloc[i[0]].title)

# %%
recommend("Avatar")
# Out:
# Falcon Rising
# Aliens vs Predator: Requiem
# Predators
# Battle: Los Angeles
# Independence Day
# The Twilight Saga: Breaking Dawn - Part 2
# Meet Dave
# Lifeforce
# Attack the Block
# Edge of Tomorrow

# %% [markdown]
# # For UI

# %%
import joblib

joblib.dump(df,"model.pkl")
# Out:
# ['model.pkl']
